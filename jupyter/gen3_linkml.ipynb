# %% [markdown]
# # Linkml Gen3 Modelling
# - Goal: Create the minimum linkml yaml that validates and loads as a gen3 jsonschema
# - Make sure to install dependancies first by following the [README](../Readme.md)

# %% [markdown]
# ## Testing Schema

# %%
# Testing validation
# !cd ../ && bash scripts/test_schema.sh -s "umccr-dictionary/schema/schema_dev.json"
# Out:
# total 192
#   0 drwxr-xr-x@ 3 harrijh  staff    96B Jan 17 15:53 .
#   0 drwxr-xr-x@ 3 harrijh  staff    96B Jan 17 15:46 ..
# 192 -rw-r--r--@ 1 harrijh  staff    94K Jan 17 15:55 schema_dev.json
# Using .env-sample
# Validating Data Dictionary: schema_dev
# [2025-01-17 04:55:28,122][data-simulator][   INFO] Data simulator initialization...
# [2025-01-17 04:55:28,123][data-simulator][   INFO] Loading dictionary from url http://ddvis/schema/schema_dev.json
# [2025-01-17 04:55:28,160][data-simulator][   INFO] Initializing graph...
# [2025-01-17 04:55:28,161][data-simulator][   INFO] Validating...
# [2025-01-17 04:55:28,161][data-simulator][   INFO] Done!

# %%
# Viewing schema
# !cd ../ && bash scripts/test_schema.sh -s "umccr-dictionary/schema/schema_dev.json" -v
# Out:
# total 192
#   0 drwxr-xr-x@ 3 harrijh  staff    96B Jan 17 15:53 .
#   0 drwxr-xr-x@ 3 harrijh  staff    96B Jan 17 15:46 ..
# 192 -rw-r--r--@ 1 harrijh  staff    94K Jan 17 15:56 schema_dev.json
# Using .env-sample
# Validating Data Dictionary: schema_dev
# [2025-01-17 04:56:16,062][data-simulator][   INFO] Data simulator initialization...
# [2025-01-17 04:56:16,063][data-simulator][   INFO] Loading dictionary from url http://ddvis/schema/schema_dev.json
# [2025-01-17 04:56:16,105][data-simulator][   INFO] Initializing graph...
# [2025-01-17 04:56:16,105][data-simulator][   INFO] Validating...
# [2025-01-17 04:56:16,106][data-simulator][   INFO] Done!
